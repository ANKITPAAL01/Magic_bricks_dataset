# %%
##import major libraries

import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(' MagicBricks.csv')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
#Data description and Data information

df.describe()  #it will work with numeric values and continue values
# Out:
#                Area          BHK     Bathroom      Parking       Per_Sqft  \
# count   1214.000000  1214.000000  1212.000000  1182.000000     973.000000
# mean    1451.850751     2.778418     2.523927     1.708122   15574.885920
# std     1586.472855     0.946811     1.017723     5.717177   21574.389007
# min       28.000000     1.000000     1.000000     1.000000    1259.000000
# 25%      800.000000     2.000000     2.000000     1.000000    6154.000000
# 50%     1150.000000     3.000000     2.000000     1.000000   10838.000000
# 75%     1620.000000     3.000000     3.000000     2.000000   17647.000000
# max    24300.000000    10.000000     7.000000   114.000000  183333.000000
#
#               Price
# count  1.214000e+03
# mean   2.079898e+07
# std    2.561308e+07
# min    1.000000e+06
# 25%    5.600000e+06
# 50%    1.400000e+07
# 75%    2.500000e+07
# max    2.400000e+08

# %%
#information regarding to dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214 entries, 0 to 1213
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1214 non-null   float64
#  1   BHK          1214 non-null   int64
#  2   Bathroom     1212 non-null   float64
#  3   Furnishing   1214 non-null   object
#  4   Location     1214 non-null   object
#  5   District     1214 non-null   object
#  6   Locality     1214 non-null   object
#  7   Parking      1182 non-null   float64
#  8   Status       1214 non-null   object
#  9   Transaction  1214 non-null   object
#  10  Type         1209 non-null   object
#  11  Per_Sqft     973 non-null    float64
#  12  Price        1214 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 123.4+ KB

# %%
#chcking missing values in a dataset

df.isnull()
# Out:
#        Area    BHK  Bathroom  Furnishing  Location  District  Locality  \
# 0     False  False     False       False     False     False     False
# 1     False  False     False       False     False     False     False
# 2     False  False     False       False     False     False     False
# 3     False  False     False       False     False     False     False
# 4     False  False     False       False     False     False     False
# ...     ...    ...       ...         ...       ...       ...       ...
# 1209  False  False     False       False     False     False     False
# 1210  False  False     False       False     False     False     False
# 1211  False  False     False       False     False     False     False
# 1212  False  False     False       False     False     False     False
# 1213  False  False     False       False     False     False     False
#
#       Parking  Status  Transaction   Type  Per_Sqft  Price
# ...

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       0
# Location         0
# District         0
# Locality         0
# Parking         32
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# Price            0
# dtype: int64

# %%
#filling null values with appropriate data

df.Bathroom=df.Bathroom.fillna(df.Bathroom.median())
df.Parking=df.Parking.fillna(df.Parking.median())
df.Type=df.Type.fillna('unknown')
df.Per_Sqft=df.Per_Sqft.fillna(df.Per_Sqft.median())

# %%
#checking null values again

df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Location       0
# District       0
# Locality       0
# Parking        0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# Price          0
# dtype: int64

# %%
#saving a clean file in local system

df.to_csv('magic_bricks_cleandata.csv')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...

# %%
#using countplot with district
sns.countplot(x=df.District)
# Out:
# <Axes: xlabel='District', ylabel='count'>

# %%
df.District.value_counts()
# Out:
# South Delhi          459
# West Delhi           150
# East Delhi           135
# North West Delhi     122
# South West Delhi      95
# South West Delhi      87
# Shahdara              75
# South East Delhi      59
# Central Delhi         32
# Name: District, dtype: int64

# %%
#compare prices of karol bagh and patel nagar

df[df.Location=='Karol Bagh']
# Out:
#        Area  BHK  Bathroom      Furnishing    Location       District  \
# 0     950.0    2       2.0       Furnished  Karol Bagh  Central Delhi
# 1     535.0    2       1.0       Furnished  Karol Bagh  Central Delhi
# 2    1280.0    3       3.0       Furnished  Karol Bagh  Central Delhi
# 3    1135.0    3       3.0       Furnished  Karol Bagh  Central Delhi
# 4    1135.0    3       3.0       Furnished  Karol Bagh  Central Delhi
# 5    1135.0    3       3.0       Furnished  Karol Bagh  Central Delhi
# 6    1135.0    3       3.0       Furnished  Karol Bagh  Central Delhi
# 176  1332.0    3       2.0  Semi-Furnished  Karol Bagh  Central Delhi
# 177   530.0    4       1.0  Semi-Furnished  Karol Bagh  Central Delhi
# 178   720.0    2       1.0  Semi-Furnished  Karol Bagh  Central Delhi
# 179   675.0    2       2.0  Semi-Furnished  Karol Bagh  Central Delhi
# 180  1206.0    3       3.0  Semi-Furnished  Karol Bagh  Central Delhi
# ...

# %%
df[df.Location=='Patel Nagar']
# Out:
#         Area  BHK  Bathroom      Furnishing     Location    District  \
# 165   1800.0    3       3.0       Furnished  Patel Nagar  West Delhi
# 166     70.0    2       3.0       Furnished  Patel Nagar  West Delhi
# 167    900.0    2       2.0       Furnished  Patel Nagar  West Delhi
# 168    900.0    3       2.0       Furnished  Patel Nagar  West Delhi
# 808   2000.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 809   1530.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 810    100.0    3       2.0  Semi-Furnished  Patel Nagar  West Delhi
# 811   1800.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 812    200.0    1       1.0  Semi-Furnished  Patel Nagar  West Delhi
# 813   1782.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 814    900.0    3       2.0  Semi-Furnished  Patel Nagar  West Delhi
# 815   1680.0    4       5.0  Semi-Furnished  Patel Nagar  West Delhi
# 816   2000.0    4       4.0  Semi-Furnished  Patel Nagar  West Delhi
# ...

# %%
df.groupby('District')['Price'].sum()
# Out:
# District
# Central Delhi          677540000
# East Delhi            1511130000
# North West Delhi       795550000
# Shahdara               827720000
# South Delhi          13717840000
# South East Delhi       813500000
# South West Delhi      2226100000
# South West Delhi      1100370000
# West Delhi            3580210000
# Name: Price, dtype: int64

# %%
#how much money you want to buy property in specific district

plt.barh(df.groupby('District')['Price'].sum().index,df.groupby('District')['Price'].sum())
# Out:
# <BarContainer object of 9 artists>

# %%
#creating a heatmap

plt.title('heatmap')
sns.heatmap(df[['Area','BHK','Bathroom','Parking','Per_Sqft','Price']].corr(),annot=True)
# Out:
# <Axes: title={'center': 'heatmap'}>

# %%
#plotting line plot with dataset .
#with matplotlib
# we are unable to check the points as they are large thats we use marker .

plt.title('Area and Price')
plt.plot(df.Area.head(15),df.Price.head(15),marker='o')

# %%
#visulisation lineplot with data set with 
#seaborn

sns.lineplot(x=df.Area.head(15),y=df.Price.head(15),marker='*',linestyle='--',ms=10)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
#scatter plot with diffrent libraries

#matplotlib scatter plot

# %%
plt.scatter(df.Area,df.Price)

# %%
#seaborn

sns.scatterplot(x=df.Area,y=df.Price)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
# we can classify or diffrentiate the categories in seaborn with hue parameter.

sns.scatterplot(x=df.Area,y=df.Price,hue=df.Furnishing)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
#bar plot with matplotlib
#in barplot x aixs must be categorical .

# %%
df.Furnishing.value_counts()
# Out:
# Semi-Furnished    677
# Unfurnished       361
# Furnished         176
# Name: Furnishing, dtype: int64

# %%
plt.bar(df.Furnishing.value_counts().index,df.Furnishing.value_counts().values)
# Out:
# <BarContainer object of 3 artists>

# %%
df.Furnishing.value_counts().values
# Out:
# array([677, 361, 176], dtype=int64)

# %%
#bar plot with seaborn

# %%
sns.barplot(x=df.Furnishing.value_counts().index,y=df.Furnishing.value_counts().values)
# Out:
# <Axes: >

# %%
#if you want to creat bar plot horizontal .

sns.barplot(x=df.Furnishing.value_counts().values,y=df.Furnishing.value_counts().index)
# Out:
# <Axes: >

# %%
#pie plot in matplotlib

df.Furnishing.value_counts(normalize=True).round(2)
# Out:
# Semi-Furnished    0.56
# Unfurnished       0.30
# Furnished         0.14
# Name: Furnishing, dtype: float64

# %%
plt.pie(df.Furnishing.value_counts(),labels=df.Furnishing.value_counts().index,autopct='%1.1f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f317a69790>,
# ...
#  [Text(-0.19817289506562194, 1.0820016190659376, 'Semi-Furnished'),
#   Text(-0.2979679207716298, -1.0588744581823815, 'Unfurnished'),
#   Text(0.987867943237228, -0.4838563079306179, 'Furnished')],
#  [Text(-0.10809430639943014, 0.5901827013086931, '55.8%'),
#   Text(-0.16252795678452533, -0.577567886281299, '29.7%'),
#   Text(0.5388370599475789, -0.26392162250760975, '14.5%')])

# %%
#line plot with seaborn
#we can diffrentiate data according coloumn with an argumnt named hue.

sns.lineplot(x=df.Price,y=df.Area,hue=df.Furnishing,marker="*",ms=10)
# Out:
# <Axes: xlabel='Price', ylabel='Area'>

# %%
#scatter plot with seaborn and hue parameter

sns.scatterplot(x=df.Area,y=df.Price,hue=df.Furnishing)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
#regression plot in seaborn 

sns.regplot(x=df.Area,y=df.Price)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
#bar chart in seaborn

sns.barplot(x=df.Furnishing,y=df.Area,ci=False)
# Out:
# <Axes: xlabel='Furnishing', ylabel='Area'>

# %%
#if we want to make this bar horizontalabs

sns.barplot(x=df.Area,y=df.Furnishing,ci=False)
# Out:
# <Axes: xlabel='Area', ylabel='Furnishing'>

# %%
#statistical analysis
#histogram (it will take only x)

sns.histplot(x=df.Price,hue=df.Furnishing)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
#kdeplot

sns.kdeplot(df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
#KDE PLOT WITH HISTOGRAM

sns.distplot(df.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df.Area)
# Out:
# <Axes: xlabel='Area', ylabel='Density'>

# %%
#histplot

sns.histplot(df.Price,kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
#countplot

sns.countplot(x=df.Furnishing)
# Out:
# <Axes: xlabel='Furnishing', ylabel='count'>

# %%
sns.countplot(x=df.Transaction)
# Out:
# <Axes: xlabel='Transaction', ylabel='count'>

# %%
#swarmplot and strip plot in seaborn 

sns.stripplot(x=df.Furnishing,y=df.Price,hue=df.Furnishing)
# Out:
# <Axes: xlabel='Furnishing', ylabel='Price'>

# %%
#swarmplot

sns.swarmplot(x=df.Furnishing,y=df.Price,hue=df.Furnishing)
# Out:
# <Axes: xlabel='Furnishing', ylabel='Price'>

# %%
#pairplot

sns.pairplot(df,hue='Furnishing')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# ...
